# %% [markdown]
# <a href="https://colab.research.google.com/github/rikiulirniam/Object-Oriented-Programming/blob/main/Jobsheet%201%20-%20Dasar%20Pemrograman%20Algoritma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laporan Praktikum dan Penugasan
# ---

# %% [markdown]
# ## Praktikum 1: Tipe data dasar

# %%
# Number
# Int
angka_int = 10
print(angka_int, type(angka_int))
# Float
angka_float = 3.24
print(angka_float, type(angka_float))
# Complex
angka_complex = 2 + 3j
print(angka_complex, type(angka_complex))

# Boolean
is_active = True
print(is_active, type(is_active))

# String
text = "Hello, Python"
print(text, type(text))

# List (Mutable)
daftar_angka = [1, 2, 3, 4, 5]
print(daftar_angka, type(daftar_angka))

# Tuple (Imutable)
koordinat = (10, 20)
print(koordinat, type(koordinat))

# Dictionary
data_mahasiswa = {
    "nama" : "Riki",
    "nim" : "43325022",
    "jurusan" : "Teknik Informatika"
}
print(data_mahasiswa, type(data_mahasiswa))

# Set(unique & unsorted)
himpunan_angka = {1, 2, 3, 4, 5}
print(himpunan_angka, type(himpunan_angka))

# Convert type data
nilai_str = "80"
print(nilai_str, type(nilai_str))
nilai_int = int(nilai_str) # str to int
print(nilai_int, type(nilai_int))
# Out:
# 10 <class 'int'>
# 3.24 <class 'float'>
# (2+3j) <class 'complex'>
# True <class 'bool'>
# Hello, Python <class 'str'>
# [1, 2, 3, 4, 5] <class 'list'>
# (10, 20) <class 'tuple'>
# {'nama': 'Riki', 'nim': '43325022', 'jurusan': 'Teknik Informatika'} <class 'dict'>
# {1, 2, 3, 4, 5} <class 'set'>
# 80 <class 'str'>
# 80 <class 'int'>

# %% [markdown]
# ## Praktikum 2: Variable dan Operasi Dasar

# %%
# Deklarasi Variable
nama = "Budi"
umur = 18
tinggi = 165.5
is_student = True
print("Nama : ", nama)
print("Umur : ", umur)
print("Tinggi : ", tinggi)
print("Is Student : ", is_student)

# Operasi Aritmatika
a=10
b=3

penjumlahan= a + b
pengurangan= a - b
perkalian= a * b
pembagian= a / b
pembagian_bulat= a // b
modulus= a % b
pangkat= a ** b

print("\nOperasi Aritmatika")
print(f"Penjumlahan: {a} + {b} = {penjumlahan}")
print(f"Pengurangan: {a} - {b} = {pengurangan}")
print(f"Perkalian: {a} * {b} = {perkalian}")
print(f"Pembagian: {a} / {b} = {pembagian}")
print(f"Pembagian Bulat: {a} // {b} = {pembagian_bulat}")
print(f"Modulus: {a} % {b} = {modulus}")
print(f"Pangkat: {a} ** {b} = {pangkat}")

# Operasi Perbandingan
lebih_besar = a > b
kurang_dari = a < b
sama_dengan = a == b
tidak_sama_dengan = a != b
lebih_besar_sama_dengan = a >= b
kurang_dari_sama_dengan = a <= b
print("\nOperasi Perbandingan")
print(f"{a} > {b} = {lebih_besar}")
print(f"{a} < {b} = {kurang_dari}")
print(f"{a} == {b} = {sama_dengan}")
print(f"{a} != {b} = {tidak_sama_dengan}")
print(f"{a} >= {b} = {lebih_besar_sama_dengan}")
print(f"{a} <= {b} = {kurang_dari_sama_dengan}")


# Operasi Logika
x = True
y = False

logika_and = x and y
logika_or = x or y
logika_not = not x

print("\nOperasi Logika")
print(f"x = {x}, y = {y}")
print(f"{x} and {y} = {logika_and}")
print(f"{x} or {y} = {logika_or}")
print(f"not {x} = {logika_not}")

# Contoh Penggunaan
if a > b and b > 0 :
    print("\na lebih besar dari b dan b lebih dari 0")
else:
    print("Kondisi tidak terpenuhi")
# Out:
# Nama :  Budi
# Umur :  18
# Tinggi :  165.5
# Is Student :  True
#
# Operasi Aritmatika
# Penjumlahan: 10 + 3 = 13
# Pengurangan: 10 - 3 = 7
# Perkalian: 10 * 3 = 30
# Pembagian: 10 / 3 = 3.3333333333333335
# Pembagian Bulat: 10 // 3 = 3
# Modulus: 10 % 3 = 1
# Pangkat: 10 ** 3 = 1000
#
# Operasi Perbandingan
# 10 > 3 = True
# 10 < 3 = False
# 10 == 3 = False
# 10 != 3 = True
# 10 >= 3 = True
# 10 <= 3 = False
#
# Operasi Logika
# x = True, y = False
# True and False = False
# True or False = True
# not True = False
#
# a lebih besar dari b dan b lebih dari 0

# %% [markdown]
# ## Praktikum 3:  Percabangan (if-else)

# %%
# -*- coding: utf-8 -*-

# 1. IF Sederhana
# Program hanya mengeksekusi blok jika kondisinya True

nilai = 85
print("Contoh IF Sederhana:")
if nilai > 80:
    print("Selamat! Anda lulus dengan nilai tinggi.\n")


# 2. IF-ELSE
# Jika kondisi True, eksekusi blok if; jika False, eksekusi blok else

umur = 17
print("Contoh IF-ELSE:")
if umur >= 18:
    print("Anda sudah cukup umur untuk mendapatkan SIM.")
else:
    print("Anda belum cukup umur untuk mendapatkan SIM.\n")


# 3. IF-ELIF-ELSE
# Menangani banyak kondisi secara berurutan.
# Jika ada kondisi yang terpenuhi, blok yang bersangkutan dieksekusi,
# lalu program melewati blok kondisi setelahnya.

hari = "Rabu"
print("Contoh IF-ELIF-ELSE:")
if hari == "Senin":
    print("Hari Senin - Saatnya kembali bekerja!")
elif hari == "Selasa":
    print("Hari Selasa - Jadwal rapat mingguan.")
elif hari == "Rabu":
    print("Hari Rabu - Ada diskon di beberapa toko.")
else:
    print("Hari lainnya - Atur jadwalmu dengan baik.\n")


# 4. IF Bersarang (Nested IF)
# Kondisi di dalam kondisi, biasa digunakan jika kita perlu
# memeriksa sub-kondisi setelah kondisi pertama terpenuhi.

suhu = 35
print("Contoh IF Bersarang (Nested IF):")
if suhu > 30:
    print("Cuaca cukup panas.")
    if suhu > 40:
        print("Bahkan sangat terik! Disarankan banyak minum air.")
    else:
	    print("Masih relatif normal, tapi tetap jaga kesehatan.")
else:
    print("Cuaca sepertinya cukup sejuk.\n")


# 5. Menggabungkan Percabangan dengan Operasi Logika
# Memeriksa beberapa kondisi sekaligus dengan and, or, not 58:
nilai_teori = 75
nilai_praktik = 80

print("Contoh IF dengan Operasi Logika AND/OR:")
if nilai_teori >= 70 and nilai_praktik >= 70:
    print("Anda lulus karena nilai teori dan praktik memadai.")
elif nilai_teori < 70 and nilai_praktik < 70:
    print("Anda perlu meningkatkan nilai teori dan praktik.")
elif nilai_teori < 70:
    print("Anda perlu meningkatkan nilai teori.")
else:
    print("Anda perlu meningkatkan nilai praktik.")

# 6. Penggunaan If Ternary (atau Conditional Expression)
# Bentuk ringkas: <hasil_if_true> if <kondisi> else <hasil_if_false>
angka = -5
print("\nContoh If Ternary (Conditional Expression):")
status = "Positif" if angka > 0 else "Negatif atau Nol"
print("Angka =", angka, "=>", status)
# Out:
# Contoh IF Sederhana:
# Selamat! Anda lulus dengan nilai tinggi.
#
# Contoh IF-ELSE:
# Anda belum cukup umur untuk mendapatkan SIM.
#
# Contoh IF-ELIF-ELSE:
# Hari Rabu - Ada diskon di beberapa toko.
# Contoh IF Bersarang (Nested IF):
# Cuaca cukup panas.
# Masih relatif normal, tapi tetap jaga kesehatan.
# Contoh IF dengan Operasi Logika AND/OR:
# Anda lulus karena nilai teori dan praktik memadai.
#
# Contoh If Ternary (Conditional Expression):
# Angka = -5 => Negatif atau Nol

# %% [markdown]
# ## Praktikum 4:  Perulangan (for, while)

# %%
# 1. FOR Loop dengan range()
print("1) FOR loop dengan range()")
for i in range(5):
    print("Perulangan ke-", i)
# range(5) menghasilkan nilai 0, 1, 2, 3, dan 4
# Sehingga perulangan akan berjalan sebanyak 5 kali
print() # pemisah output

# 2. FOR Loop untuk mengiterasi List
print("2) FOR loop mengiterasi list")
buah = ["apel", "mangga", "jeruk", "pisang"]
for item in buah:
    print("Buah:", item)
# Loop akan mengeksekusi setiap elemen dalam list "buah"
print()

# 3. WHILE Loop
print("3) WHILE loop sederhana")
count = 0
while count < 5:
    print("count =", count)
    count += 1 # increment
# Perulangan while terus dijalankan selama kondisi (count < 5) bernilai True
print()

# 4. BREAK pada Loop
print("4) BREAK di dalam loop")
for i in range(10):
    if i == 3:
        print("Loop dihentikan pada i =", i)
        break # mengakhiri loop saat i = 3
    print("i =", i)
# Keyword break langsung menghentikan keseluruhan perulangan
print()

# 5. CONTINUE pada Loop
print("5) CONTINUE di dalam loop")
for i in range(5):
    if i == 2:
        print("Lewati i =", i, "dengan continue")
        continue # melewati iterasi saat ini dan lanjut ke iterasi berikutnya
    print("i =", i)
# Saat i = 2, baris print("i =", i) tidak akan dieksekusi
print()

# 6. NESTED Loop (Loop Bersarang) 54: print("6) NESTED loop")
for i in range(3):	# Loop luar (outer loop)
    for j in range(2):	# Loop dalam (inner loop)
        print(f"i={i}, j={j}")
# Pada setiap iterasi i, loop j akan berjalan dari 0 sampai 1
print()

# 7. Memanfaatkan ELSE pada Loop
print("7) ELSE pada loop for/while")
# Python memiliki fitur unik: blok else pada loop
# Blok else akan dieksekusi jika loop selesai tanpa di-break.
for x in range(3):
    print("x =", x)
else:
    print("Loop for telah selesai tanpa break.\n")
y = 0
while y < 3:
    print("y =", y)
    y += 1
else:
    print("Loop while telah selesai tanpa break.\n")
# 8. PASS sebagai placeholder
print("8) PASS (placeholder)")
for i in range(3):
    if i == 1:
        pass # pass tidak melakukan apa-apa, digunakan sebagai placeholder
    print("i =", i)
# Out:
# 1) FOR loop dengan range()
# Perulangan ke- 0
# Perulangan ke- 1
# Perulangan ke- 2
# Perulangan ke- 3
# Perulangan ke- 4
#
# 2) FOR loop mengiterasi list
# Buah: apel
# Buah: mangga
# Buah: jeruk
# Buah: pisang
#
# 3) WHILE loop sederhana
# count = 0
# count = 1
# count = 2
# count = 3
# count = 4
#
# 4) BREAK di dalam loop
# i = 0
# i = 1
# i = 2
# Loop dihentikan pada i = 3
#
# 5) CONTINUE di dalam loop
# i = 0
# i = 1
# Lewati i = 2 dengan continue
# i = 3
# i = 4
#
# i=0, j=0
# i=0, j=1
# i=1, j=0
# i=1, j=1
# i=2, j=0
# i=2, j=1
#
# 7) ELSE pada loop for/while
# x = 0
# x = 1
# x = 2
# Loop for telah selesai tanpa break.
#
# y = 0
# y = 1
# y = 2
# Loop while telah selesai tanpa break.
#
# 8) PASS (placeholder)
# i = 0
# i = 1
# i = 2

# %% [markdown]
# # Penugasan
# ---

# %% [markdown]
# ### Penugasan 3: BMI (Body Mass Index)

# %%
bb = float(input("Masukkan berat badan (kg): "))
tb = float(input("Masukkan tinggi badan (M): "))
bmi = bb / (tb**2)
print(f"BMI Anda adalah {bmi}")
# Out:
# Masukkan berat badan (kg): 52.2
# Masukkan tinggi badan (M): 1.65
# BMI Anda adalah 19.173553719008268

# %% [markdown]
# ### Penugasan 4: Check ganjil, genap, atau prime

# %%
num = int(input("Masukkan bilangan : "))
status = num % 2 == 0
isPrime = False
if num > 1:
    isPrime = True
    for i in range(2, int(num**0.5) + 1):
        if (num % i) == 0:
            isPrime = False
            break

prime_label = " & prima" if isPrime else ""

if status:
    print(f"{num} adalah bilangan genap{prime_label}")
else:
    print(f"{num} adalah bilangan ganjil{prime_label}")
# Out:
# Masukkan bilangan : 9
# 9 adalah bilangan ganjil
